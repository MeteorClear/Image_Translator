# %% [markdown]
# https://github.com/aGIToz/PyInpaint

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from pyinpaint import Inpaint

# %%
img = cv2.imread('test1.jpg')
msk1 = cv2.imread('mask1.png')
msk2 = cv2.imread('mask2.png')
print(img.shape, msk1.shape, msk2.shape)
plt.imshow(img)

# %%
plt.imshow(msk1)

# %%
#plt.imshow(msk2)

# %%
#inpaint = Inpaint(org_img, mask, ps)
#inpainted_img = inpaint(k_boundary, k_search, k_patch)

# %%
print(img.shape, msk1.shape)
# Out:
# (594, 769, 3) (594, 769, 3)

# %%
inpaint1 = Inpaint('test1.jpg', 'mask1.png', 3)
inpainted_img1 = inpaint1(16, 300, 3)

#inpaint2 = Inpaint('test1.jpg', 'mask2.png', 3)
#inpainted_img2 = inpaint2(16, 300, 3)
# Out:
# # of pixels to be inpainted are 35520: 100%|██████████|35520/35520
# # of pixels to be inpainted are 411444:   0%|          |0/411444
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 5
#       2 inpainted_img1 = inpaint1(16, 300, 3)
#       4 inpaint2 = Inpaint('test1.jpg', 'mask2.png', 3)
# ----> 5 inpainted_img2 = inpaint2(16, 300, 3)
#
# File c:\Users\PC\.conda\envs\olv\lib\site-packages\pyinpaint\inpaint.py:36, in Inpainting.__call__(self, k_boundary, k_search, k_patch)
#      30 def __call__(self, k_boundary=4, k_search=1000, k_patch=5):
#      31   """
#      32   k_boundary: used for finding the boundary pixels
#      33   k_search: used for search in the neighborhood of the boundary pixels
#      34   k_patch: used for creating a dynamic non-local graph
#      35   """
# ---> 36   inpainted_img =  self.forward(k_boundary, k_search, k_patch)
# ...

# %%
plt.imshow(inpainted_img1)

# %%
plt.imshow(inpainted_img2)
